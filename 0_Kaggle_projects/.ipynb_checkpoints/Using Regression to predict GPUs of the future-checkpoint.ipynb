# %% [markdown]
# # Regression / GPUs Dataset Analysis

# %% [markdown]
# <b>Note:</b> Using regression models we will try to predict how powerfull will Graphics Cards be in 2025.

# %% [markdown]
# ### Moore's law: Number of transistors in a dense integrated circuit doubles approximately every two years.

# %% [markdown]
# <img src='https://upload.wikimedia.org/wikipedia/commons/f/fe/GeForce4_Ti_4800SE_NV28_GPU.jpg'>

# %% [markdown]
# # Table of Contents

# %% [markdown]
# * [1. Importing dataset and data preprocessing](#importing_dataset_and_data_preprocessing) <br>
#    * [1.1. Dataset import](#dataset_import) <br>
#    * [1.2. Let's summarize the Dataset](#lets_summarize_the_dataset) <br>
#    * [1.3. Data preprocessing & feature engineering](#data_preprocessing) <br>
# <br>
# * [2. Basic data visualization](#basic_data_visualization) <br>
#    * [2.1. Grouping GPUs by Release Year](#grouping_gpus_by_release_year) <br>
#    * [2.2. GPU Memory vs Year of Release by Manufacturer](#gpu_memory_vs_year_of_release_by_manufacturer) <br>
# <br>
# * [3. GPU Memory](#gpu_memory) <br>
#     * [3.1. GPU Memory vs Year of Release (Scatter Plot)](#gpu_memory_vs_year_of_release) <br>
#     * [3.2. Mean GPU Memory vs Year of Release (Line Plot)](#mean_gpu_memory_vs_year_of_release) <br>
#     * [3.3. Polynomial regression prediction model](#polynomial_regression_prediction_model) <br>
#     * [3.4. Predicting GPUs mean memory size in 2025](#predicting_gpus_mean_memory_size_in_2025) <br>
# <br>
# * [4. Bibliography](#bibliography) <br>

# %% [markdown]
# ## 1. Importing dataset and data preprocessing
# <a id="importing_dataset_and_data_preprocessing"></a>

# %% [markdown]
# ### 1.1. Dataset import
# <a id="dataset_import"></a>

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

import plotly.offline as py
py.init_notebook_mode(connected=True)
import plotly.graph_objs as go
import plotly.tools as tls
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>

# %%
# Let's import dataset from csv file
dataset = pd.read_csv('../00_Datasets/GPUs/All_GPUs.csv')

# %% [markdown]
# ### 1.2. Let's try to summarize the Dataset
# <a id="lets_summarize_the_dataset"></a>

# %%
dataset.head(100)
# Out:
#                    Architecture Best_Resolution Boost_Clock Core_Speed  \
# 0                   Tesla G92b              NaN         NaN    738 MHz
# 1                      R600 XT       1366 x 768         NaN       \n-
# 2                     R600 PRO       1366 x 768         NaN       \n-
# 3                        RV630       1024 x 768         NaN       \n-
# 4                        RV630       1024 x 768         NaN       \n-
# 5                        RV630       1024 x 768         NaN       \n-
# 6                R700 RV790 XT      1920 x 1080         NaN    870 MHz
# 7                      R600 GT       1024 x 768         NaN       \n-
# 8               Pitcairn XT GL      1920 x 1080         NaN       \n-
# 9                        RV100              NaN         NaN       \n-
# 10                   NV28GL A2              NaN         NaN       \n-
# 11                 Fermi GF110      1920 x 1080         NaN    650 MHz
# 12                Kepler GK110              NaN         NaN    705 MHz
# 13                Kepler GK110      2560 x 1600         NaN    706 MHz
# 14                       RV200              NaN         NaN       \n-
# 15   GCN 1.1 Oland XT + Kaveri       1600 x 900   1100 MHz    1050 MHz
# 16             Kepler GK104 x2              NaN         NaN       \n-
# 17                Kepler GK110              NaN         NaN    732 MHz
# 18               Skylake GT3-E       1366 x 768   1000 MHz     300 MHz
# 19                        R360       1024 x 768         NaN       \n-
# 20                 Fermi GF100              NaN         NaN    575 MHz
# 21                 Fermi GF100              NaN         NaN    575 MHz
# 22                     NV25 A2              NaN         NaN       \n-
# 23                   NV28GL A2              NaN         NaN       \n-
# 24               Skylake GT3-E       1366 x 768   1000 MHz     300 MHz
# 25                        NV28              NaN         NaN       \n-
# 26                 Fermi GF100              NaN         NaN    575 MHz
# 27               Skylake GT3-E       1366 x 768   1050 MHz     300 MHz
# 28               Skylake GT3-E       1366 x 768    950 MHz     300 MHz
# 29                 Haswell GT3       1366 x 768   1100 MHz     200 MHz
# ..                          ...             ...         ...        ...
# 71                Terrascale 2              NaN         NaN         \n
# 72                Terrascale 3              NaN         NaN         \n
# 73                        R200              NaN         NaN       \n-
# 74                        R360       1024 x 768         NaN       \n-
# 75                       RV360        800 x 600         NaN       \n-
# 76                       RV350              NaN         NaN       \n-
# 77                       RV360        800 x 600         NaN       \n-
# 78                        R300              NaN         NaN       \n-
# 79                        R300              NaN         NaN       \n-
# 80                       RV350              NaN         NaN       \n-
# 81                       RV280              NaN         NaN       \n-
# 82                       RV280              NaN         NaN       \n-
# 83                        R200              NaN         NaN       \n-
# 84                          NaN             NaN         NaN       \n-
# 85                          NaN             NaN         NaN       \n-
# 86                          NaN             NaN         NaN       \n-
# 87                       RV250              NaN         NaN       \n-
# 88                          NaN             NaN         NaN       \n-
# 89                          NaN             NaN         NaN       \n-
# 90                          NaN             NaN         NaN       \n-
# 91                          NaN             NaN         NaN       \n-
# 92                          NaN             NaN         NaN       \n-
# 93                          NaN             NaN         NaN       \n-
# 94                          NaN             NaN         NaN       \n-
# 95                          NaN             NaN         NaN       \n-
# 96                          NaN             NaN         NaN       \n-
# 97                          NaN             NaN         NaN       \n-
# 98        GCN 2.0 Hawaii XT GL      2560 x 1600         NaN       \n-
# 99                  Tahiti Pro              NaN         NaN       \n-
# 100                         NaN             NaN         NaN       \n-
#
#      DVI_Connection Dedicated Direct_X  DisplayPort_Connection  \
# 0               2.0       Yes  DX 10.0                     NaN
# 1               2.0       Yes    DX 10                     NaN
# 2               2.0       Yes    DX 10                     NaN
# 3               2.0       Yes    DX 10                     NaN
# 4               2.0       Yes    DX 10                     NaN
# 5               2.0       Yes    DX 10                     NaN
# 6               1.0       Yes  DX 10.1                     NaN
# 7               2.0       Yes    DX 10                     NaN
# 8               0.0       Yes  DX 11.2                     NaN
# 9               NaN       Yes     DX 7                     NaN
# 10              2.0       Yes   DX 8.1                     NaN
# 11              2.0       Yes  DX 12.0                     0.0
# 12              0.0       Yes  DX 12.0                     NaN
# 13              0.0       Yes  DX 12.0                     NaN
# 14              NaN       Yes     DX 7                     NaN
# 15              1.0       Yes  DX 12.0                     0.0
# 16              0.0       Yes  DX 11.1                     NaN
# 17              0.0       Yes  DX 12.0                     NaN
# 18              NaN        No  DX 12.1                     NaN
# 19              1.0       Yes     DX 9                     0.0
# 20              1.0       Yes  DX 12.0                     NaN
# 21              1.0       Yes  DX 12.0                     NaN
# 22              2.0       Yes   DX 8.1                     NaN
# 23              2.0       Yes   DX 8.1                     NaN
# 24              NaN        No  DX 12.1                     NaN
# 25              2.0       Yes   DX 8.1                     NaN
# 26              1.0       Yes  DX 12.0                     NaN
# 27              NaN        No  DX 12.1                     NaN
# 28              NaN        No  DX 12.1                     NaN
# 29              NaN        No  DX 11.1                     NaN
# ..              ...       ...      ...                     ...
# 71              0.0       Yes    DX 11                     NaN
# 72              0.0       Yes    DX 11                     NaN
# 73              NaN       Yes   DX 8.1                     NaN
# 74              1.0       Yes     DX 9                     NaN
# 75              1.0       Yes   DX 9.0                     NaN
# 76              1.0       Yes     DX 9                     NaN
# 77              1.0       Yes   DX 9.0                     NaN
# 78              NaN       Yes     DX 9                     NaN
# 79              0.0       Yes     DX 9                     NaN
# 80              NaN       Yes     DX 9                     NaN
# 81              1.0       Yes   DX 8.1                     NaN
# 82              NaN       Yes   DX 8.1                     NaN
# 83              0.0       Yes   DX 8.1                     NaN
# 84              1.0       Yes  DX 10.1                     NaN
# 85              1.0       Yes  DX 9.0c                     NaN
# 86              NaN       Yes  DX 9.0c                     NaN
# 87              NaN       Yes   DX 8.1                     NaN
# 88              2.0       Yes    DX 10                     NaN
# 89              2.0       Yes    DX 10                     NaN
# 90              2.0       Yes  DX 9.0c                     NaN
# 91              1.0       Yes    DX 10                     NaN
# 92              NaN       Yes     DX 9                     NaN
# 93              2.0       Yes  DX 9.0b                     NaN
# 94              2.0       Yes    DX 10                     NaN
# 95              NaN       Yes  DX 9.0c                     NaN
# 96              2.0       Yes  DX 9.0c                     NaN
# 97              2.0       Yes  DX 9.0c                     NaN
# 98              0.0       Yes  DX 11.2                     NaN
# 99              0.0       Yes  DX 11.1                     NaN
# 100             NaN       Yes     DX 9                     NaN
#
#      HDMI_Connection Integrated   ...    Resolution_WxH SLI_Crossfire Shader  \
# 0                0.0         No   ...         2560x1600           Yes    4.0
# 1                0.0         No   ...         2560x1600           Yes    4.0
# 2                0.0         No   ...         2560x1600           Yes    4.0
# 3                0.0         No   ...         2560x1600           Yes    4.0
# 4                0.0         No   ...         2560x1600           Yes    4.0
# 5                0.0         No   ...         2560x1600           Yes    4.0
# 6                1.0         No   ...         2560x1600           Yes    4.1
# 7                0.0         No   ...         2560x1600           Yes    4.0
# 8                0.0         No   ...         4096x2160           Yes    5.0
# 9                NaN         No   ...         1600x1200            No    1.0
# 10               0.0         No   ...               NaN            No    1.3
# 11               1.0         No   ...         2560x1600           Yes    5.0
# 12               0.0         No   ...         4096x2160            No    5.0
# 13               0.0         No   ...         4096x2160           Yes    5.0
# 14               NaN         No   ...         1600x1200            No    NaN
# 15               1.0         No   ...         2560x1600           Yes    5.0
# 16               0.0         No   ...         4096x2160            No    5.0
# 17               0.0         No   ...         4096x2160           Yes    5.0
# 18               NaN        Yes   ...         4096x2304            No    5.0
# 19               0.0         No   ...         2048x1536            No    2.0
# 20               0.0         No   ...         2560x1600            No    5.0
# 21               0.0         No   ...         2560x1600            No    5.0
# 22               0.0         No   ...               NaN            No    1.3
# 23               0.0         No   ...               NaN            No    1.3
# 24               NaN        Yes   ...         4096x2304            No    5.0
# 25               0.0         No   ...               NaN            No    1.3
# 26               0.0         No   ...         2560x1600            No    5.0
# 27               NaN        Yes   ...         4096x2304            No    5.0
# 28               NaN        Yes   ...         4096x2304            No    5.0
# 29               NaN        Yes   ...         2560x1600            No    5.0
# ..               ...        ...   ...               ...           ...    ...
# 71               0.0         No   ...         2560x1600            No    5.0
# 72               0.0         No   ...         2560x1600            No    5.0
# 73               NaN         No   ...         2048x1536            No    1.4
# 74               0.0         No   ...         2048x1536            No    2.0
# 75               0.0         No   ...         2048x1536            No    2.0
# 76               0.0         No   ...         2048x1536            No    2.0
# 77               0.0         No   ...         2048x1536            No    2.0
# 78               NaN         No   ...         2048x1536            No    2.0
# 79               0.0         No   ...         2048x1536            No    2.0
# 80               NaN         No   ...         2048x1536            No    2.0
# 81               0.0         No   ...         2048x1536            No    1.4
# 82               NaN         No   ...         2048x1536            No    1.4
# 83               0.0         No   ...               NaN            No    1.4
# 84               1.0         No   ...         2560x1600            No    4.0
# 85               1.0         No   ...         3840x2400            No    3.0
# 86               NaN         No   ...         2048x1536            No    3.0
# 87               NaN         No   ...         2048x1536            No    1.4
# 88               NaN         No   ...         2560x1600            No    4.0
# 89               NaN         No   ...         2048x1536            No    4.0
# 90               1.0         No   ...         2048x1536            No    3.0
# 91               1.0         No   ...         2560x1600            No    4.0
# 92               NaN         No   ...         2048x1536            No    NaN
# 93               0.0         No   ...         2048x1536            No    3.0
# 94               NaN         No   ...         2048x1536            No    4.0
# 95               NaN         No   ...         2048x1536            No    3.0
# 96               0.0         No   ...         2048x1536            No    3.0
# 97               NaN         No   ...         2048x1536            No    3.0
# 98               0.0         No   ...         4096x2160           Yes    5.0
# 99               0.0         No   ...         4096x2160           Yes    5.0
# 100              NaN         No   ...         2048x1536            No    2.0
#
#       TMUs  Texture_Rate VGA_Connection Release_Year Release_Month  \
# 0     64.0   47 GTexel/s            0.0         2009             3
# 1     16.0   12 GTexel/s            0.0         2007             5
# 2     16.0   10 GTexel/s            0.0         2007            12
# 3      8.0    7 GTexel/s            0.0         2007             7
# 4      8.0    6 GTexel/s            0.0         2007             6
# 5      8.0    6 GTexel/s            0.0         2007             6
# 6     40.0   35 GTexel/s            1.0         2009             7
# 7     12.0    7 GTexel/s            0.0         2007            11
# 8     80.0   62 GTexel/s            0.0         2014             1
# 9      NaN           NaN            NaN         2001             1
# 10     8.0    2 GTexel/s            0.0         2002            11
# 11    56.0   36 GTexel/s            0.0         2011             7
# 12     NaN           NaN            0.0         2012            11
# 13   240.0  169 GTexel/s            0.0         2013            11
# 14     NaN           NaN            1.0         2002             1
# 15    28.0   62 GTexel/s            1.0         2015             5
# 16     NaN           NaN            0.0         2012             5
# 17     NaN           NaN            0.0         2012            11
# 18     8.0    8 GTexel/s            NaN         2015             9
# 19     8.0    3 GTexel/s            1.0         2003            10
# 20     NaN           NaN            0.0         2010             9
# 21     NaN           NaN            0.0         2011             7
# 22     8.0    2 GTexel/s            0.0         2002             2
# 23     8.0    2 GTexel/s            0.0         2002            11
# 24     8.0    8 GTexel/s            NaN         2015             9
# 25     8.0    2 GTexel/s            0.0         2002            11
# 26     NaN           NaN            0.0         2010             5
# 27     8.0    8 GTexel/s            NaN         2015             9
# 28     8.0    8 GTexel/s            NaN         2015             9
# 29     8.0    9 GTexel/s            NaN         2013             6
# ..     ...           ...            ...          ...           ...
# 71     NaN           NaN            0.0         2012             7
# 72     NaN           NaN            0.0         2012             6
# 73     NaN           NaN            NaN         2001             1
# 74     8.0    3 GTexel/s            1.0         2003             3
# 75     4.0    2 GTexel/s            1.0         2005             8
# 76     NaN           NaN            1.0         2004             1
# 77     4.0    2 GTexel/s            1.0         2003            10
# 78     NaN           NaN            NaN         2002            10
# 79     NaN           NaN            0.0         2002            10
# 80     NaN           NaN            NaN         2003             1
# 81     NaN           NaN            1.0         2004             1
# 82     NaN           NaN            NaN         2003             4
# 83     NaN           NaN            1.0         2003             4
# 84     NaN           NaN            1.0         2008             1
# 85     NaN           NaN            1.0         2006             3
# 86     NaN           NaN            NaN         2004             6
# 87     NaN           NaN            NaN         2002             8
# 88     NaN           NaN            NaN         2007             1
# 89     NaN           NaN            NaN         2007             1
# 90     NaN           NaN            2.0         2006             4
# 91     NaN           NaN            1.0         2007             1
# 92     NaN           NaN            NaN         2002            11
# 93     NaN           NaN            0.0         2005             1
# 94     NaN           NaN            NaN         2007             1
# 95     NaN           NaN            NaN         2006             1
# 96     NaN           NaN            2.0         2006             4
# 97     NaN           NaN            2.0         2006             8
# 98   176.0  164 GTexel/s            0.0         2014             3
# 99     NaN           NaN            0.0         2012             6
# 100    NaN           NaN            1.0         2004             6
#
#          Release PixelNum
# 0    2009.250000   480000
# 1    2007.416667  1049088
# 2    2008.000000  1049088
# 3    2007.583333   786432
# 4    2007.500000   786432
# 5    2007.500000   786432
# 6    2009.583333  2073600
# 7    2007.916667   786432
# 8    2014.083333  2073600
# 9    2001.083333   480000
# 10   2002.916667   480000
# 11   2011.583333  2073600
# 12   2012.916667   480000
# 13   2013.916667  4096000
# 14   2002.083333   480000
# 15   2015.416667  1440000
# 16   2012.416667   480000
# 17   2012.916667   480000
# 18   2015.750000  1049088
# 19   2003.833333   786432
# 20   2010.750000   480000
# 21   2011.583333   480000
# 22   2002.166667   480000
# 23   2002.916667   480000
# 24   2015.750000  1049088
# 25   2002.916667   480000
# 26   2010.416667   480000
# 27   2015.750000  1049088
# 28   2015.750000  1049088
# 29   2013.500000  1049088
# ..           ...      ...
# 71   2012.583333   480000
# 72   2012.500000   480000
# 73   2001.083333   480000
# 74   2003.250000   786432
# 75   2005.666667   480000
# 76   2004.083333   480000
# 77   2003.833333   480000
# 78   2002.833333   480000
# 79   2002.833333   480000
# 80   2003.083333   480000
# 81   2004.083333   480000
# 82   2003.333333   480000
# 83   2003.333333   480000
# 84   2008.083333   480000
# 85   2006.250000   480000
# 86   2004.500000   480000
# 87   2002.666667   480000
# 88   2007.083333   480000
# 89   2007.083333   480000
# 90   2006.333333   480000
# 91   2007.083333   480000
# 92   2002.916667   480000
# 93   2005.083333   480000
# 94   2007.083333   480000
# 95   2006.083333   480000
# 96   2006.333333   480000
# 97   2006.666667   480000
# 98   2014.250000  4096000
# 99   2012.500000   480000
# 100  2004.500000   480000
#
# [100 rows x 38 columns]

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3406 entries, 0 to 3405
# Data columns (total 34 columns):
# Architecture              3344 non-null object
# Best_Resolution           2764 non-null object
# Boost_Clock               1446 non-null object
# Core_Speed                3406 non-null object
# DVI_Connection            2656 non-null float64
# Dedicated                 3392 non-null object
# Direct_X                  3400 non-null object
# DisplayPort_Connection    857 non-null float64
# HDMI_Connection           2643 non-null float64
# Integrated                3392 non-null object
# L2_Cache                  3406 non-null object
# Manufacturer              3406 non-null object
# Max_Power                 2781 non-null object
# Memory                    2986 non-null object
# Memory_Bandwidth          3285 non-null object
# Memory_Bus                3344 non-null object
# Memory_Speed              3301 non-null object
# Memory_Type               3350 non-null object
# Name                      3406 non-null object
# Notebook_GPU              3406 non-null object
# Open_GL                   3366 non-null float64
# PSU                       2231 non-null object
# Pixel_Rate                2862 non-null object
# Power_Connector           2697 non-null object
# Process                   2943 non-null object
# ROPs                      2868 non-null object
# Release_Date              3406 non-null object
# Release_Price             556 non-null object
# Resolution_WxH            3211 non-null object
# SLI_Crossfire             3406 non-null object
# Shader                    3299 non-null float64
# TMUs                      2868 non-null float64
# Texture_Rate              2862 non-null object
# VGA_Connection            2648 non-null float64
# dtypes: float64(7), object(27)
# memory usage: 904.8+ KB

# %% [markdown]
# <b> NOTE: </b> Right away we can see that there is lots of undefined values. Let's use "Missingno" package which is a most useful and convenient tool in visualising missing values in the dataset. There are only few columns that can by use as reliable source of information for our analysis. Most of columns are incomplete or in wrong format. We will perform data preprocessing to make some columns usefull in our analysis.

# %%
import missingno as msno
# Nullity or missing values by columns
msno.matrix(df=dataset, figsize=(20, 14), color=(0.8, 0.8, 0.8))

# %% [markdown]
# ### 1.3. Data preprocessing & feature engineering
# <a id="data_preprocessing"></a>

# %%
dataset['Release_Date']=dataset['Release_Date'].str[1:-1]
dataset=dataset[dataset['Release_Date'].str.len()==11]
dataset['Release_Date']=pd.to_datetime(dataset['Release_Date'], format='%d-%b-%Y')
dataset['Release_Year']=dataset['Release_Date'].dt.year
dataset['Release_Month']=dataset['Release_Date'].dt.month
dataset['Release']=dataset['Release_Year'] + dataset['Release_Month']/12

# %%
dataset['Memory'] = dataset['Memory'].str[:-3].fillna(0).astype(int)

# %%
def countPixels(x):
    if pd.isnull(x):
        return 800*600;
    else:
        values = x.split(' x ')
        return(int(values[0]) * int(values[1]))

dataset['PixelNum'] = dataset['Best_Resolution'].apply(lambda x: countPixels(x))

# %% [markdown]
# ## 2. Basic data visualization
# <a id="basic_data_visualization"></a>

# %% [markdown]
# ### 2.1. Grouping GPUs by Release Year
# <a id="grouping_gpus_by_release_year"></a>

# %%
plt.figure(figsize=(16,8))
sns.set_style("whitegrid")
sns.countplot(x="Release_Year", data=dataset, palette="hls");
plt.title('Grouping GPUs by Release Year', fontsize=20, fontweight='bold', y=1.05,)
plt.xlabel('Number GPUs', fontsize=15)
plt.ylabel('Release Year', fontsize=15)
plt.show()

# %% [markdown]
# ### 2.2. GPU Memory vs Year of Release by Manufacturer
# <a id="gpu_memory_vs_year_of_release_by_manufacturer"></a>

# %%
data = []

for manufacturer in dataset['Manufacturer'].unique():
    
    trace_dataset = dataset.loc[dataset['Manufacturer'] == manufacturer]
    
    trace = go.Scatter(
        x = trace_dataset['Release_Year'],
        y = trace_dataset['Memory'],
        mode = 'markers',
        name = manufacturer,
        marker= dict(symbol="circle",
                    size = trace_dataset['PixelNum']/100000,
                    opacity = 0.4,
                    line= dict(width=1,
                               color = 'rgb(255, 255, 255)'
                              ),
        ),
        text= dataset['Name']
    )
    
    data.append(trace)
    
layout = dict(title = 'GPU Memory vs Year of Release by Manufacturer',
              width=1000,
              height=800,
              paper_bgcolor='rgb(243, 243, 243)',
              plot_bgcolor='rgb(243, 243, 243)',
              yaxis = dict(title= 'GPUs Memory',
                           ticklen= 5,
                           gridcolor='rgb(255, 255, 255)',
                           gridwidth= 2),
              xaxis = dict(title= 'Year of Release',
                           ticklen= 5,
                           gridcolor='rgb(255, 255, 255)',
                           gridwidth= 2)
             )

fig= go.Figure(data=data, layout=layout)
py.iplot(fig)
# Out:
# <div id="226bef0b-b68f-436f-9727-8edd4feb0b97" style="height: 800px; width: 1000px;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("226bef0b-b68f-436f-9727-8edd4feb0b97", [{"type": "scatter", "x": [2009, 2002, 2011, 2012, 2013, 2012, 2012, 2010, 2011, 2002, 2002, 2002, 2010, 2002, 2002, 2002, 2002, 2002, 2016, 2017, 2013, 2014, 2014, 2014, 2015, 2015, 2013, 2015, 2015, 2015, 2013, 2013, 2016, 2013, 2016, 2013, 2013, 2013, 2014, 2013, 2013, 2009, 2009, 2009, 2009, 2010, 2006, 2007, 2008, 2008, 2012, 2002, 2008, 2008, 2008, 2008, 2008, 2008, 2008, 2008, 2008, 2008, 2008, 2008, 2008, 2008, 2008, 2008, 2008, 2008, 2008, 2008, 2008, 2008, 2002, 2008, 2002, 2010, 2002, 2008, 2002, 2008, 2007, 2010, 2009, 2007, 2008, 2009, 2006, 2007, 2005, 2010, 2008, 2013, 2006, 2008, 2013, 2012, 2012, 2012, 2012, 2012, 2011, 2013, 2013, 2012, 2011, 2011, 2011, 2007, 2010, 2012, 2011, 2010, 2011, 2010, 2007, 2007, 2010, 2007, 2007, 2006, 2006, 2006, 2007, 2007, 2007, 2005, 2014, 2006, 2006, 2005, 2006, 2014, 2011, 2014, 2006, 2009, 2011, 2011, 2011, 2011, 2011, 2011, 2011, 2012, 2011, 2011, 2011, 2011, 2011, 2011, 2011, 2011, 2011, 2009, 2010, 2011, 2009, 2009, 2009, 2009, 2009, 2016, 2016, 2009, 2017, 2016, 2009, 2009, 2016, 2010, 2009, 2009, 2010, 2009, 2009, 2009, 2009, 2009, 2011, 2010, 2010, 2010, 2010, 2010, 2009, 2010, 2010, 2011, 2010, 2010, 2010, 2014, 2016, 2011, 2010, 2010, 2014, 2012, 2014, 2014, 2014, 2014, 2010, 2013, 2010, 2010, 2014, 2010, 2010, 2014, 2010, 2010, 2014, 2010, 2011, 2014, 2013, 2010, 2013, 2012, 2012, 2012, 2012, 2012, 2012, 2014, 2012, 2010, 2012, 2012, 2012, 2012, 2012, 2012, 2012, 2012, 2012, 2012, 2012, 2012, 2012, 2012, 2012, 2012, 2012, 2012, 2011, 2012, 2014, 2011, 2011, 2011, 2013, 2013, 2013, 2013, 2012, 2013, 2013, 2013, 2013, 2013, 2013, 2013, 2013, 2013, 2013, 2013, 2013, 2013, 2013, 2013, 2013, 2013, 2014, 2013, 2013, 2013, 2013, 2013, 2012, 2014, 2016, 2014, 2014, 2016, 2014, 2014, 2014, 2015, 2015, 2015, 2015, 2015, 2011, 2015, 2016, 2015, 2015, 2015, 2013, 2016, 2015, 2015, 2016, 2015, 2015, 2015, 2015, 2015, 2006, 2006, 2006, 2006, 2015, 2006, 2005, 2005, 2006, 2006, 2006, 2006, 2006, 2007, 2007, 2006, 2007, 2007, 2007, 2007, 2007, 2007, 2007, 2006, 2008, 2007, 2009, 2012, 2008, 2011, 2011, 2007, 2008, 2013, 2015, 2000, 2014, 2012, 2014, 2014, 2014, 2013, 2013, 2014, 2008, 2010, 2010, 2010, 2011, 2012, 2011, 2008, 2009, 2008, 2010, 2011, 2007, 2008, 2009, 2008, 2008, 2008, 2008, 2008, 2008, 2008, 2008, 2008, 2008, 2008, 2008, 2008, 2008, 2008, 2008, 2008, 2008, 2008, 2006, 2008, 2008, 2006, 2006, 2006, 2006, 2005, 2007, 2006, 2006, 2005, 2006, 2006, 2006, 2006, 2006, 2006, 2006, 2006, 2007, 2007, 2007, 2006, 2005, 2006, 2005, 2010, 2007, 2007, 2007, 2006, 2007, 2007, 2007, 2007, 2008, 2007, 2007, 2007, 2007, 2007, 2007, 2007, 2007, 2007, 2007, 2007, 2008, 2010, 2008, 2007, 2007, 1999, 2007, 2007, 1999, 1999, 1999, 2010, 2012, 1998, 2009, 2007, 2006, 2004, 1999, 2009, 2007, 2006, 2005, 2009, 2009, 2009, 2008, 2006, 2006, 2007, 2004, 2005, 2007, 2007, 2004, 2011, 2003, 2004, 2003, 2003, 2003, 2006, 2011, 2005, 2005, 2003, 2003, 1999, 2003, 2004, 2014, 2003, 2011, 2009, 2010, 2001, 2010, 2009, 2010, 2012, 2009, 2010, 2010, 2012, 2012, 2012, 2015, 2012, 2012, 2012, 2012, 2012, 2012, 2012, 2012, 2012, 2012, 2017, 2012, 2016, 2017, 2016, 2016, 2017, 2009, 2017, 2017, 2017, 2017, 2017, 2017, 2017, 2017, 2017, 2017, 2017, 2017, 2017, 2017, 2017, 2017, 2017, 2017, 2017, 2017, 2017, 2017, 2017, 2017, 2017, 2017, 2017, 2017, 2017, 2017, 2017, 2017, 2017, 2017, 2017, 2017, 2017, 2017, 2017, 2017, 2017, 2016, 2016, 2016, 2016, 2016, 2016, 2016, 2016, 2016, 2016, 2017, 2016, 2016, 2016, 2016, 2016, 2016, 2016, 2016, 2016, 2016, 2016, 2016, 2016, 2016, 2016, 2016, 2016, 2016, 2016, 2016, 2016, 2016, 2016, 2016, 2016, 2016, 2016, 2016, 2016, 2016, 2016, 2016, 2016,  ...

# %% [markdown]
# ## 3. GPU Memory
# <a id="gpu_memory"></a>

# %% [markdown]
# ### 3.1. GPU Memory vs Year of Release (Scatter Plot)
# <a id="gpu_memory_vs_year_of_release"></a>

# %% [markdown]
# <b>NOTE:</b> Firstly, lets prepere simple scatter plot and look at relation between year of release and memory size of GPU.

# %%
plt.figure(figsize=(16,10))
sns.set_style("whitegrid")
plt.title('GPU Memory vs Year of Release', fontsize=20, fontweight='bold', y=1.05,)
plt.xlabel('Year of Release', fontsize=15)
plt.ylabel('GPU Memory', fontsize=15)

years = dataset["Release"].values
memory = dataset["Memory"].values

plt.scatter(years, memory, edgecolors='black')
plt.show()

# %% [markdown]
# ### 3.2. Mean GPU Memory vs Year of Release (Line Plot)
# <a id="mean_gpu_memory_vs_year_of_release"></a>

# %% [markdown]
# <b>NOTE:</b> Now we will calculate mean and median Memory Size of GPU for each year and create line plots to visualize the upward trend. Right away we see that Moore's law quite accurate.

# %%
year_arr = dataset.sort_values("Release_Year")['Release_Year'].unique()
memory_arr_mean = dataset.groupby('Release_Year')['Memory'].mean().values
memory_arr_median = dataset.groupby('Release_Year')['Memory'].median().values

# %%
plt.figure()
plt.figure(figsize=(16,8))
plt.title('Mean GPU Memory vs Year of Release', fontsize=20, fontweight='bold', y=1.05,)
plt.xlabel('Year of Release', fontsize=15)
plt.ylabel('GPU Memory', fontsize=15)
sns.set_style("whitegrid")
plt.plot(year_arr, memory_arr_mean, label="Mean")
plt.plot(year_arr, memory_arr_median, label="Median")
plt.legend(loc=4, prop={'size': 15}, frameon=True,shadow=True, facecolor="white", edgecolor="black")
plt.show()

# %% [markdown]
# ### 3.3. Polynomial regression prediction model
# <a id="polynomial_regression_prediction_model"></a>

# %%
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures

# Fitting Polynomial Regression to the dataset
poly_reg_2 = PolynomialFeatures(degree = 2, include_bias=False)
poly_reg_3 = PolynomialFeatures(degree = 3, include_bias=False)

X_poly_2 = poly_reg_2.fit_transform(year_arr.reshape(-1, 1))
X_poly_3 = poly_reg_3.fit_transform(year_arr.reshape(-1, 1))

lin_reg_2 = LinearRegression()
lin_reg_3 = LinearRegression()

lin_reg_2.fit(X_poly_2, memory_arr_mean)
lin_reg_3.fit(X_poly_3, memory_arr_mean)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
plt.figure()
plt.figure(figsize=(16,8))
X_grid = np.arange(min(year_arr), max(year_arr), 0.1)
X_grid = X_grid.reshape((len(X_grid), 1))
plt.plot(year_arr, memory_arr_mean, label="Mean")
plt.plot(year_arr, memory_arr_median, label="Median")
plt.plot(X_grid, lin_reg_2.predict(poly_reg_2.fit_transform(X_grid)), label="Prediction 2deg")
plt.plot(X_grid, lin_reg_3.predict(poly_reg_3.fit_transform(X_grid)), label="Prediction 3deg")
plt.title('Mean GPU Memory vs Year of Release', fontsize=20, fontweight='bold', y=1.05,)
plt.xlabel('Year of Release', fontsize=15)
plt.ylabel('GPU Memory', fontsize=15)
sns.set_style("whitegrid")
plt.legend(loc=4, prop={'size': 15}, frameon=True,shadow=True, facecolor="white", edgecolor="black")
plt.show()

# %%
score_2 = lin_reg_2.score(X_poly_2, memory_arr_mean)
score_3 = lin_reg_3.score(X_poly_3, memory_arr_mean)
print('The coefficient R^2 for 2nd degree polynomial is equel = ' + str(score_2))
print('The coefficient R^2 for 3rd degree polynomial is equel = ' + str(score_3))
print('Lets select 3rd degree polynomial, becouse is seems to fit data better.')
# Out:
# The coefficient R^2 for 2nd degree polynomial is equel = 0.949268225996
# The coefficient R^2 for 3rd degree polynomial is equel = 0.985326074617
# Lets select 3rd degree polynomial, becouse is seems to fit data better.

# %% [markdown]
# ### 3.4. Predicting GPUs mean memory size in 2025
# <a id="predicting_gpus_mean_memory_size_in_2025"></a>

# %%
memory_2015 = lin_reg_3.predict(poly_reg_3.fit_transform(2025))
memory_2015
# Out:
# array([ 25863.28773117])

# %% [markdown]
# ## 4. Bibliography
# <a id="bibliography"></a>

# %% [markdown]
# 1. Moore's law: https://en.wikipedia.org/wiki/Moore%27s_law
# 2. "Missingno" GitHub repository: https://github.com/ResidentMario/missingno
# 3. Polynomial regression theory: https://neutrium.net/mathematics/least-squares-fitting-of-a-polynomial/
